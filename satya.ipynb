# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyawf03/Pemrograman_Python/blob/main/satya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/Collab Notebook
# Out:
# /content/drive/My Drive/Collab Notebook

# %%
ls
# Out:
# 3scene/  best_weight_scene_mobileNet.h5  mantap.jpg  satya.ipynb

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("3scene")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((64, 64))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print(labels)
# Out:
# ['forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', ...

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)
# Out:
# [[0 1 0]
#  [0 1 0]
#  [0 1 0]
#  ...
#  [0 0 1]
#  [0 0 1]
#  [0 0 1]]

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.30)
print(trainX.shape)
print(testX.shape)
# Out:
# (663, 64, 64, 3)
# (285, 64, 64, 3)

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
        Flatten(input_shape=(64*64*3,)),
        Dense(100, activation="relu", name="layer1"),
        Dense(16, activation="relu", name="layer2"),
        Dense(16, activation="relu", name="layer3"),
        Dense(16, activation="relu", name="layer4"),
        Dense(3, activation = "softmax", name="layer5"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# layer1 (Dense)               (None, 100)               1228900
# _________________________________________________________________
# layer2 (Dense)               (None, 16)                1616
# _________________________________________________________________
# layer3 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer4 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer5 (Dense)               (None, 3)                 51
# =================================================================
# Total params: 1,231,111
# Trainable params: 1,231,111
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=50, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_4_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_4_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1835 - accuracy: 0.4668WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_4_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 21/21 [==============================] - 0s 11ms/step - loss: 1.1471 - accuracy: 0.4781 - val_loss: 0.9755 - val_accuracy: 0.5439
# Epoch 2/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.9356 - accuracy: 0.5385 - val_loss: 0.9135 - val_accuracy: 0.5158
# Epoch 3/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.8775 - accuracy: 0.5792 - val_loss: 1.0219 - val_accuracy: 0.4667
# Epoch 4/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.8749 - accuracy: 0.5566 - val_loss: 0.8699 - val_accuracy: 0.6000
# Epoch 5/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.8325 - accuracy: 0.5943 - val_loss: 0.7746 - val_accuracy: 0.6561
# Epoch 6/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.7769 - accuracy: 0.6229 - val_loss: 0.8939 - val_accuracy: 0.4877
# Epoch 7/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.7450 - accuracy: 0.6516 - val_loss: 0.7267 - val_accuracy: 0.7228
# Epoch 8/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.7074 - accuracy: 0.6817 - val_loss: 0.7110 - val_accuracy: 0.7333
# Epoch 9/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6419 - accuracy: 0.7406 - val_loss: 0.6743 - val_accuracy: 0.7263
# Epoch 10/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5939 - accuracy: 0.7783 - val_loss: 0.6726 - val_accuracy: 0.7158
# Epoch 11/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5721 - accuracy: 0.7662 - val_loss: 0.7057 - val_accuracy: 0.6912
# Epoch 12/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5738 - accuracy: 0.7572 - val_loss: 0.6256 - val_accuracy: 0.7614
# Epoch 13/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5182 - accuracy: 0.8039 - val_loss: 0.6224 - val_accuracy: 0.7404
# Epoch 14/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5279 - accuracy: 0.7858 - val_loss: 0.6025 - val_accuracy: 0.7544
# Epoch 15/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4467 - accuracy: 0.8431 - val_loss: 0.6603 - val_accuracy: 0.7123
# Epoch 16/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4714 - accuracy: 0.8069 - val_loss: 0.6322 - val_accuracy: 0.7018
# Epoch 17/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4835 - accuracy: 0.7964 - val_loss: 0.5919 - val_accuracy: 0.7579
# Epoch 18/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4246 - accuracy: 0.8386 - val_loss: 0.6702 - val_accuracy: 0.7368
# Epoch 19/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4245 - accuracy: 0.8356 - val_loss: 0.6419 - val_accuracy: 0.7509
# Epoch 20/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3952 - accuracy: 0.8477 - val_loss: 0.6026 - val_accuracy: 0.7544
# Epoch 21/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3830 - accuracy: 0.8688 - val_loss: 0.6350 - val_accuracy: 0.7544
# Epoch 22/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3603 - accuracy: 0.8612 - val_loss: 0.7532 - val_accuracy: 0.6912
# Epoch 23/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3732 - accuracy: 0.8507 - val_loss: 0.6195 - val_accuracy: 0.7509
# Epoch 24/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3351 - accuracy: 0.8733 - val_loss: 0.6025 - val_accuracy: 0.7544
# Epoch 25/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3188 - accuracy: 0.8854 - val_loss: 0.7217 - val_accuracy: 0.7719
# Epoch 26/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.8793 - val_loss: 0.8401 - val_accuracy: 0.7509
# Epoch 27/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.8311 - val_loss: 0.6673 - val_accuracy: 0.7474
# Epoch 28/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3397 - accuracy: 0.8673 - val_loss: 0.6097 - val_accuracy: 0.7579
# Epoch 29/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3264 - accuracy: 0.8899 - val_loss: 0.9081 - val_accuracy: 0.6421
# Epoch 30/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3491 - accuracy: 0.8673 - val_loss: 0.6553 - val_accuracy: 0.7474
# Epoch 31/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2635 - accuracy: 0.9170 - val_loss: 0.6341 - val_accuracy: 0.7684
# Epoch 32/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2574 - accuracy: 0.9050 - val_loss: 0.6813 - val_accuracy: 0.7649
# Epoch 33/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3235 - accuracy: 0.8733 - val_loss: 0.6741 - val_accuracy: 0.7684
# Epoch 34/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2460 - accuracy: 0.9170 - val_loss: 0.6555 - val_accuracy: 0.7754
# Epoch 35/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2415 - accuracy: 0.9125 - val_loss: 0.7447 - val_accuracy: 0.7263
# Epoch 36/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2185 - accuracy: 0.9321 - val_loss: 0.6812 - val_accuracy: 0.7614
# Epoch 37/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2526 - accuracy: 0.9050 - val_loss: 0.9451 - val_accuracy: 0.6807
# Epoch 38/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2876 - accuracy: 0.8914 - val_loss: 0.6877 - val_accuracy: 0.7789
# Epoch 39/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2132 - accuracy: 0.9397 - val_loss: 0.7301 - val_accuracy: 0.7263
# Epoch 40/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1932 - accuracy: 0.9306 - val_loss: 0.7207 - val_accuracy: 0.7474
# Epoch 41/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1929 - accuracy: 0.9367 - val_loss: 1.0638 - val_accuracy: 0.6456
# Epoch 42/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3854 - accuracy: 0.8462 - val_loss: 0.7941 - val_accuracy: 0.7298
# Epoch 43/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2128 - accuracy: 0.9261 - val_loss: 0.6990 - val_accuracy: 0.7930
# Epoch 44/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1651 - accuracy: 0.9487 - val_loss: 0.7954 - val_accuracy: 0.7789
# Epoch 45/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1968 - accuracy: 0.9351 - val_loss: 0.6948 - val_accuracy: 0.7719
# Epoch 46/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1620 - accuracy: 0.9517 - val_loss: 0.7180 - val_accuracy: 0.7719
# Epoch 47/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1505 - accuracy: 0.9593 - val_loss: 0.7308 - val_accuracy: 0.7825
# Epoch 48/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9517 - val_loss: 0.7659 - val_accuracy: 0.7860
# Epoch 49/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1564 - accuracy: 0.9412 - val_loss: 0.7267 - val_accuracy: 0.7754
# Epoch 50/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1371 - accuracy: 0.9578 - val_loss: 0.7478 - val_accuracy: 0.7789

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_4_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.79      0.74      0.77        97
#       forest       0.88      0.71      0.79       104
#      highway       0.69      0.90      0.78        84
#
#     accuracy                           0.78       285
#    macro avg       0.79      0.79      0.78       285
# weighted avg       0.79      0.78      0.78       285

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='mantap.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('mantap.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_4_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (1, 64, 64, 3).
# [[0.9367064  0.04984519 0.01344833]]
# ['coast']
